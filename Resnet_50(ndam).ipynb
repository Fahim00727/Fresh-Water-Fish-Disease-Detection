# %% [markdown]
# <a href="https://colab.research.google.com/github/abdullahamruf/Fish-Diseses/blob/main/fish_resnet_50(ndam).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2
import os
from tensorflow import keras
import glob as gb
import pandas as pd
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.layers.experimental.preprocessing import RandomFlip, RandomRotation
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPool2D ,LeakyReLU
from keras.preprocessing.image import ImageDataGenerator

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
IMG_SIZE = (299, 299) # resolution

BATCH_SIZE = 128

# %%
from tensorflow.keras.preprocessing import image_dataset_from_directory

IMG_SIZE = (299, 299)  # resolution
BATCH_SIZE = 128

# Define the directories for training, testing, and validation
train_directory = '/content/drive/MyDrive/dataset/Fishtrain'
test_directory = '/content/drive/MyDrive/dataset/fishtest'
valid_directory = '/content/drive/MyDrive/dataset/Fishvalid'

# Create TensorFlow datasets
train_dataset = image_dataset_from_directory(
    train_directory,
    shuffle=True,
    labels='inferred',
    batch_size=BATCH_SIZE,
    image_size=IMG_SIZE,
    color_mode='rgb',
    seed=42
)

test_dataset = image_dataset_from_directory(
    test_directory,
    shuffle=True,
    labels='inferred',
    batch_size=BATCH_SIZE,
    image_size=IMG_SIZE,
    color_mode='rgb',
    seed=42
)

valid_dataset = image_dataset_from_directory(
    valid_directory,
    shuffle=True,
    labels='inferred',
    batch_size=BATCH_SIZE,
    image_size=IMG_SIZE,
    color_mode='rgb',
    seed=42
)

# Optional: You can also specify the class names if you have a specific order for your classes
class_names = train_dataset.class_names

# Print class names
print("Class Names:", class_names)
# Out:
# Found 1616 files belonging to 7 classes.
# Found 199 files belonging to 7 classes.
# Found 178 files belonging to 7 classes.
# Class Names: ['Argulus', 'Broken antennae and rostrum', 'EUS', 'Healthy Fish', 'Redspot', 'THE BACTERIAL GILL ROT', 'Tail And Fin Rot']

# %%
class_names = train_dataset.class_names
class_names
# Out:
# ['Argulus',
#  'Broken antennae and rostrum',
#  'EUS',
#  'Healthy Fish',
#  'Redspot',
#  'THE BACTERIAL GILL ROT',
#  'Tail And Fin Rot']

# %%
sns.set_theme(style="whitegrid")
Data_imbalance = []
for folder in os.listdir(train_directory):
    files = gb.glob(pathname=str(train_directory + "/" + folder +"/*.*"))
    Data_imbalance.append(len(files))
plt.figure(figsize=(13,7))
sns.barplot(x=["Argulus", "Broken antennae and rostrum", "EUS", "Healthy Fish","Redspot","THE BACTERIAL GILL ROT","Tail And Fin Rot"], y=Data_imbalance, palette="rocket")
plt.show()

# %%
import os
import seaborn as sns
import matplotlib.pyplot as plt
import glob as gb

sns.set_theme(style="whitegrid")

# Assuming you already have Data_imbalance calculated
# If not, you should calculate it before using it in this code

# Print the dataset class-wise count
for folder, count in zip(["Argulus", "Broken antennae and rostrum", "EUS", "Healthy Fish","Redspot","THE BACTERIAL GILL ROT","Tail And Fin Rot"], Data_imbalance):
    print(f"Class '{folder}': {count} samples")

# Create the bar plot
plt.figure(figsize=(13,7))
sns.barplot(x=["Argulus", "Broken antennae and rostrum", "EUS", "Healthy Fish","Redspot","THE BACTERIAL GILL ROT","Tail And Fin Rot"], y=Data_imbalance, palette="rocket")
plt.show()
# Out:
# Class 'Argulus': 235 samples
# Class 'Broken antennae and rostrum': 235 samples
# Class 'EUS': 206 samples
# Class 'Healthy Fish': 235 samples
# Class 'Redspot': 235 samples
# Class 'THE BACTERIAL GILL ROT': 235 samples
# Class 'Tail And Fin Rot': 235 samples

# %%
total = 0
for i in range(0,len(Data_imbalance)) :
    total +=Data_imbalance[i]

weight_for_0 = (1 / Data_imbalance[0]) * (total / 7.0)
weight_for_1 = (1 / Data_imbalance[1]) * (total / 7.0)
weight_for_2 = (1 / Data_imbalance[2]) * (total / 7.0)
weight_for_3 = (1 / Data_imbalance[3]) * (total / 7.0)
weight_for_4 = (1 / Data_imbalance[3]) * (total / 7.0)
weight_for_5 = (1 / Data_imbalance[3]) * (total / 7.0)
weight_for_6 = (1 / Data_imbalance[3]) * (total / 7.0)
class_weight = {0: weight_for_0, 1: weight_for_1, 2: weight_for_2, 3: weight_for_3,4: weight_for_4,5: weight_for_5,6: weight_for_6}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
print('Weight for class 2: {:.2f}'.format(weight_for_2))
print('Weight for class 3: {:.2f}'.format(weight_for_3))
print('Weight for class 4: {:.2f}'.format(weight_for_4))
print('Weight for class 5: {:.2f}'.format(weight_for_5))
print('Weight for class 6: {:.2f}'.format(weight_for_6))
# Out:
# Weight for class 0: 0.98
# Weight for class 1: 0.98
# Weight for class 2: 1.12
# Weight for class 3: 0.98
# Weight for class 4: 0.98
# Weight for class 5: 0.98
# Weight for class 6: 0.98

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip("horizontal"),
  tf.keras.layers.RandomRotation(0.2),
  tf.keras.layers.RandomZoom(0.2),
  tf.keras.layers.RandomHeight(0.2),
  tf.keras.layers.RandomWidth(0.2),
])

# %%
for image, _ in train_dataset.take(1):
    plt.figure(figsize=(10, 10))
    first_image = image[0]
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        augmented_image = data_augmentation(tf.expand_dims(first_image, 3))
        plt.imshow(augmented_image[0] / 255)
        plt.axis('off')

# %%
augmented_count = 0

for image, _ in train_dataset:
    augmented_images = data_augmentation(image)
    augmented_count += augmented_images.shape[0]  # Count the number of augmented images

original_count = len(train_dataset) * BATCH_SIZE  # Total number of original images
total_count = original_count + augmented_count    # Total number of images after augmentation

increase_percentage = ((total_count - original_count) / original_count) * 100

print(f"Original image count: {original_count}")
print(f"Augmented image count: {augmented_count}")
print(f"Total image count after augmentation: {total_count}")
print(f"Increase in image count: {increase_percentage:.2f}%")
# Out:
# Original image count: 1664
# Augmented image count: 1616
# Total image count after augmentation: 3280
# Increase in image count: 97.12%

# %%
IMG_SHAPE = IMG_SIZE +(3,)
base_model = tf.keras.applications.ResNet50(input_shape=IMG_SHAPE, include_top= False, weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 1s 0us/step

# %%
type(base_model)
preprocess_input = tf.keras.applications.resnet.preprocess_input

# %%
nb_layers = len(base_model.layers)
print("Numbers of Layers =" , nb_layers)
print(base_model.layers[nb_layers - 2].name)  # pre- Last name
print(base_model.layers[nb_layers - 1].name)
# Out:
# Numbers of Layers = 175
# conv5_block3_add
# conv5_block3_out

# %%
# iterate over first batch (32 image) in trainset
image_batch, label_batch = next(iter(train_dataset))  # 32 image arrays
feature_batch = base_model(image_batch)  # run the model on those 32 image (base model with its 1000 causes classification)
print(feature_batch.shape)  # 32 for number of images in this batch and 1000 for classes
# Out:
# (128, 10, 10, 2048)

# %%
def fish_resnet50( image_shape=IMG_SIZE):
    ''' Define a tf.keras model for multi-class classification out of the InceptionV3 model '''
    image_shape = image_shape + (3,)

    resnet_model = tf.keras.applications.ResNet50(input_shape=IMG_SHAPE, include_top= False,weights='imagenet')
    resnet_model.trainable = True
    for layer in resnet_model.layers[0 : 291]:
        layer.trainable = False

    inputs = tf.keras.Input(image_shape)
    x = data_augmentation(inputs)
    x = preprocess_input(inputs)
    x = resnet_model(x , training=False)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    prediction_layer = tf.keras.layers.Dense(7 ,activation = "softmax")
    outputs = prediction_layer(x)
    model = tf.keras.Model(inputs, outputs)
    model.summary()
    return model

# %%
fish = fish_resnet50(IMG_SIZE)
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_12 (InputLayer)       [(None, 299, 299, 3)]     0
#
#  tf.__operators__.getitem (  (None, 299, 299, 3)       0
#  SlicingOpLambda)
#
#  tf.nn.bias_add (TFOpLambda  (None, 299, 299, 3)       0
#  )
#
#  resnet50 (Functional)       (None, 10, 10, 2048)      23587712
#
#  global_average_pooling2d_3  (None, 2048)              0
#   (GlobalAveragePooling2D)
#
#  dropout_3 (Dropout)         (None, 2048)              0
#
#  dense_3 (Dense)             (None, 7)                 14343
#
# =================================================================
# Total params: 23602055 (90.03 MB)
# Trainable params: 14343 (56.03 KB)
# Non-trainable params: 23587712 (89.98 MB)
# _________________________________________________________________

# %%
base_learning_rate = 0.001
fish.compile(optimizer=tf.keras.optimizers.Nadam(learning_rate=base_learning_rate),
                           loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                           metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
model_filepath="/content/drive/MyDrive/fishresnet-50-{epoch:02d}-{val_accuracy:.4f}.hdf5"
checkpoint = ModelCheckpoint(
    filepath = model_filepath ,
    monitor ='val_accuracy',
    mode = 'max' ,
    save_best_only =True ,
     verbose = 1

)

# %%
history = fish.fit(train_dataset , verbose=2 , epochs=50 ,class_weight=class_weight,
                               validation_data=valid_dataset , use_multiprocessing= True,callbacks =[checkpoint])
# Out:
# Epoch 1/50
#
# Epoch 1: val_accuracy improved from -inf to 0.53933, saving model to /content/drive/MyDrive/fishresnet-50-01-0.5393.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 13/13 - 41s - loss: 2.1207 - accuracy: 0.2494 - val_loss: 1.3013 - val_accuracy: 0.5393 - 41s/epoch - 3s/step
# Epoch 2/50
#
# Epoch 2: val_accuracy improved from 0.53933 to 0.76966, saving model to /content/drive/MyDrive/fishresnet-50-02-0.7697.hdf5
# 13/13 - 14s - loss: 1.3243 - accuracy: 0.5198 - val_loss: 0.8062 - val_accuracy: 0.7697 - 14s/epoch - 1s/step
# Epoch 3/50
#
# Epoch 3: val_accuracy improved from 0.76966 to 0.90449, saving model to /content/drive/MyDrive/fishresnet-50-03-0.9045.hdf5
# 13/13 - 16s - loss: 0.8286 - accuracy: 0.7370 - val_loss: 0.5390 - val_accuracy: 0.9045 - 16s/epoch - 1s/step
# Epoch 4/50
#
# Epoch 4: val_accuracy improved from 0.90449 to 0.92135, saving model to /content/drive/MyDrive/fishresnet-50-04-0.9213.hdf5
# 13/13 - 14s - loss: 0.6328 - accuracy: 0.8045 - val_loss: 0.4076 - val_accuracy: 0.9213 - 14s/epoch - 1s/step
# Epoch 5/50
#
# Epoch 5: val_accuracy improved from 0.92135 to 0.93820, saving model to /content/drive/MyDrive/fishresnet-50-05-0.9382.hdf5
# 13/13 - 16s - loss: 0.4767 - accuracy: 0.8676 - val_loss: 0.3396 - val_accuracy: 0.9382 - 16s/epoch - 1s/step
# Epoch 6/50
#
# Epoch 6: val_accuracy did not improve from 0.93820
# 13/13 - 13s - loss: 0.4105 - accuracy: 0.8837 - val_loss: 0.2866 - val_accuracy: 0.9382 - 13s/epoch - 974ms/step
# Epoch 7/50
#
# Epoch 7: val_accuracy did not improve from 0.93820
# 13/13 - 13s - loss: 0.3655 - accuracy: 0.9041 - val_loss: 0.2657 - val_accuracy: 0.9382 - 13s/epoch - 1s/step
# Epoch 8/50
#
# Epoch 8: val_accuracy improved from 0.93820 to 0.94944, saving model to /content/drive/MyDrive/fishresnet-50-08-0.9494.hdf5
# 13/13 - 15s - loss: 0.3114 - accuracy: 0.9183 - val_loss: 0.2395 - val_accuracy: 0.9494 - 15s/epoch - 1s/step
# Epoch 9/50
#
# Epoch 9: val_accuracy did not improve from 0.94944
# 13/13 - 13s - loss: 0.2887 - accuracy: 0.9251 - val_loss: 0.2229 - val_accuracy: 0.9494 - 13s/epoch - 986ms/step
# Epoch 10/50
#
# Epoch 10: val_accuracy improved from 0.94944 to 0.97191, saving model to /content/drive/MyDrive/fishresnet-50-10-0.9719.hdf5
# 13/13 - 15s - loss: 0.2552 - accuracy: 0.9332 - val_loss: 0.2039 - val_accuracy: 0.9719 - 15s/epoch - 1s/step
# Epoch 11/50
#
# Epoch 11: val_accuracy improved from 0.97191 to 0.97753, saving model to /content/drive/MyDrive/fishresnet-50-11-0.9775.hdf5
# 13/13 - 14s - loss: 0.2339 - accuracy: 0.9437 - val_loss: 0.1959 - val_accuracy: 0.9775 - 14s/epoch - 1s/step
# Epoch 12/50
#
# Epoch 12: val_accuracy did not improve from 0.97753
# 13/13 - 13s - loss: 0.2208 - accuracy: 0.9425 - val_loss: 0.1890 - val_accuracy: 0.9663 - 13s/epoch - 1s/step
# Epoch 13/50
#
# Epoch 13: val_accuracy did not improve from 0.97753
# 13/13 - 15s - loss: 0.2116 - accuracy: 0.9449 - val_loss: 0.1790 - val_accuracy: 0.9663 - 15s/epoch - 1s/step
# Epoch 14/50
#
# Epoch 14: val_accuracy did not improve from 0.97753
# 13/13 - 13s - loss: 0.1958 - accuracy: 0.9486 - val_loss: 0.1690 - val_accuracy: 0.9719 - 13s/epoch - 972ms/step
# Epoch 15/50
#
# Epoch 15: val_accuracy did not improve from 0.97753
# 13/13 - 14s - loss: 0.1861 - accuracy: 0.9505 - val_loss: 0.1682 - val_accuracy: 0.9775 - 14s/epoch - 1s/step
# Epoch 16/50
#
# Epoch 16: val_accuracy did not improve from 0.97753
# 13/13 - 13s - loss: 0.1804 - accuracy: 0.9561 - val_loss: 0.1662 - val_accuracy: 0.9719 - 13s/epoch - 1s/step
# Epoch 17/50
#
# Epoch 17: val_accuracy did not improve from 0.97753
# 13/13 - 14s - loss: 0.1612 - accuracy: 0.9548 - val_loss: 0.1605 - val_accuracy: 0.9775 - 14s/epoch - 1s/step
# Epoch 18/50
#
# Epoch 18: val_accuracy did not improve from 0.97753
# 13/13 - 14s - loss: 0.1615 - accuracy: 0.9610 - val_loss: 0.1537 - val_accuracy: 0.9775 - 14s/epoch - 1s/step
# Epoch 19/50
#
# Epoch 19: val_accuracy did not improve from 0.97753
# 13/13 - 14s - loss: 0.1652 - accuracy: 0.9548 - val_loss: 0.1546 - val_accuracy: 0.9775 - 14s/epoch - 1s/step
# Epoch 20/50
#
# Epoch 20: val_accuracy did not improve from 0.97753
# 13/13 - 14s - loss: 0.1517 - accuracy: 0.9585 - val_loss: 0.1531 - val_accuracy: 0.9663 - 14s/epoch - 1s/step
# Epoch 21/50
#
# Epoch 21: val_accuracy did not improve from 0.97753
# 13/13 - 14s - loss: 0.1299 - accuracy: 0.9647 - val_loss: 0.1463 - val_accuracy: 0.9719 - 14s/epoch - 1s/step
# Epoch 22/50
#
# Epoch 22: val_accuracy did not improve from 0.97753
# 13/13 - 13s - loss: 0.1341 - accuracy: 0.9666 - val_loss: 0.1467 - val_accuracy: 0.9775 - 13s/epoch - 1s/step
# Epoch 23/50
#
# Epoch 23: val_accuracy improved from 0.97753 to 0.98315, saving model to /content/drive/MyDrive/fishresnet-50-23-0.9831.hdf5
# 13/13 - 14s - loss: 0.1401 - accuracy: 0.9635 - val_loss: 0.1461 - val_accuracy: 0.9831 - 14s/epoch - 1s/step
# Epoch 24/50
#
# Epoch 24: val_accuracy did not improve from 0.98315
# 13/13 - 14s - loss: 0.1346 - accuracy: 0.9629 - val_loss: 0.1444 - val_accuracy: 0.9831 - 14s/epoch - 1s/step
# Epoch 25/50
#
# Epoch 25: val_accuracy did not improve from 0.98315
# 13/13 - 13s - loss: 0.1259 - accuracy: 0.9691 - val_loss: 0.1431 - val_accuracy: 0.9831 - 13s/epoch - 977ms/step
# Epoch 26/50
#
# Epoch 26: val_accuracy did not improve from 0.98315
# 13/13 - 13s - loss: 0.1215 - accuracy: 0.9703 - val_loss: 0.1398 - val_accuracy: 0.9831 - 13s/epoch - 1s/step
# Epoch 27/50
#
# Epoch 27: val_accuracy did not improve from 0.98315
# 13/13 - 13s - loss: 0.1210 - accuracy: 0.9715 - val_loss: 0.1456 - val_accuracy: 0.9775 - 13s/epoch - 1s/step
# Epoch 28/50
#
# Epoch 28: val_accuracy did not improve from 0.98315
# 13/13 - 14s - loss: 0.1110 - accuracy: 0.9715 - val_loss: 0.1400 - val_accuracy: 0.9775 - 14s/epoch - 1s/step
# Epoch 29/50
#
# Epoch 29: val_accuracy did not improve from 0.98315
# 13/13 - 13s - loss: 0.1141 - accuracy: 0.9653 - val_loss: 0.1372 - val_accuracy: 0.9831 - 13s/epoch - 985ms/step
# Epoch 30/50
#
# Epoch 30: val_accuracy did not improve from 0.98315
# 13/13 - 14s - loss: 0.1086 - accuracy: 0.9672 - val_loss: 0.1395 - val_accuracy: 0.9719 - 14s/epoch - 1s/step
# Epoch 31/50
#
# Epoch 31: val_accuracy did not improve from 0.98315
# 13/13 - 14s - loss: 0.1035 - accuracy: 0.9697 - val_loss: 0.1382 - val_accuracy: 0.9775 - 14s/epoch - 1s/step
# Epoch 32/50
#
# Epoch 32: val_accuracy did not improve from 0.98315
# 13/13 - 14s - loss: 0.0963 - accuracy: 0.9752 - val_loss: 0.1413 - val_accuracy: 0.9719 - 14s/epoch - 1s/step
# Epoch 33/50
#
# Epoch 33: val_accuracy did not improve from 0.98315
# 13/13 - 14s - loss: 0.1077 - accuracy: 0.9703 - val_loss: 0.1391 - val_accuracy: 0.9663 - 14s/epoch - 1s/step
# Epoch 34/50
#
# Epoch 34: val_accuracy did not improve from 0.98315
# 13/13 - 13s - loss: 0.1068 - accuracy: 0.9691 - val_loss: 0.1355 - val_accuracy: 0.9719 - 13s/epoch - 1s/step
# Epoch 35/50
#
# Epoch 35: val_accuracy did not improve from 0.98315
# 13/13 - 13s - loss: 0.1020 - accuracy: 0.9734 - val_loss: 0.1343 - val_accuracy: 0.9719 - 13s/epoch - 999ms/step
# Epoch 36/50
#
# Epoch 36: val_accuracy did not improve from 0.98315
# 13/13 - 13s - loss: 0.0898 - accuracy: 0.9746 - val_loss: 0.1381 - val_accuracy: 0.9719 - 13s/epoch - 990ms/step
# Epoch 37/50
#
# Epoch 37: val_accuracy did not improve from 0.98315
# 13/13 - 14s - loss: 0.0945 - accuracy: 0.9752 - val_loss: 0.1354 - val_accuracy: 0.9719 - 14s/epoch - 1s/step
# Epoch 38/50
#
# Epoch 38: val_accuracy did not improve from 0.98315
# 13/13 - 14s - loss: 0.0903 - accuracy: 0.9802 - val_loss: 0.1341 - val_accuracy: 0.9775 - 14s/epoch - 1s/step
# Epoch 39/50
#
# Epoch 39: val_accuracy did not improve from 0.98315
# 13/13 - 14s - loss: 0.0931 - accuracy: 0.9734 - val_loss: 0.1329 - val_accuracy: 0.9775 - 14s/epoch - 1s/step
# Epoch 40/50
#
# Epoch 40: val_accuracy did not improve from 0.98315
# 13/13 - 13s - loss: 0.1012 - accuracy: 0.9703 - val_loss: 0.1303 - val_accuracy: 0.9663 - 13s/epoch - 972ms/step
# Epoch 41/50
#
# Epoch 41: val_accuracy did not improve from 0.98315
# 13/13 - 14s - loss: 0.0905 - accuracy: 0.9740 - val_loss: 0.1299 - val_accuracy: 0.9775 - 14s/epoch - 1s/step
# Epoch 42/50
#
# Epoch 42: val_accuracy did not improve from 0.98315
# 13/13 - 13s - loss: 0.0889 - accuracy: 0.9765 - val_loss: 0.1327 - val_accuracy: 0.9775 - 13s/epoch - 1s/step
# Epoch 43/50
#
# Epoch 43: val_accuracy did not improve from 0.98315
# 13/13 - 13s - loss: 0.0868 - accuracy: 0.9771 - val_loss: 0.1333 - val_accuracy: 0.9775 - 13s/epoch - 982ms/step
# Epoch 44/50
#
# Epoch 44: val_accuracy did not improve from 0.98315
# 13/13 - 14s - loss: 0.0830 - accuracy: 0.9715 - val_loss: 0.1310 - val_accuracy: 0.9719 - 14s/epoch - 1s/step
# Epoch 45/50
#
# Epoch 45: val_accuracy did not improve from 0.98315
# 13/13 - 13s - loss: 0.0798 - accuracy: 0.9765 - val_loss: 0.1368 - val_accuracy: 0.9719 - 13s/epoch - 1s/step
# Epoch 46/50
#
# Epoch 46: val_accuracy did not improve from 0.98315
# 13/13 - 14s - loss: 0.0846 - accuracy: 0.9752 - val_loss: 0.1314 - val_accuracy: 0.9719 - 14s/epoch - 1s/step
# Epoch 47/50
#
# Epoch 47: val_accuracy did not improve from 0.98315
# 13/13 - 13s - loss: 0.0756 - accuracy: 0.9821 - val_loss: 0.1356 - val_accuracy: 0.9719 - 13s/epoch - 998ms/step
# Epoch 48/50
#
# Epoch 48: val_accuracy did not improve from 0.98315
# 13/13 - 14s - loss: 0.0824 - accuracy: 0.9728 - val_loss: 0.1346 - val_accuracy: 0.9719 - 14s/epoch - 1s/step
# Epoch 49/50
#
# Epoch 49: val_accuracy did not improve from 0.98315
# 13/13 - 13s - loss: 0.0817 - accuracy: 0.9734 - val_loss: 0.1375 - val_accuracy: 0.9719 - 13s/epoch - 1s/step
# Epoch 50/50
#
# Epoch 50: val_accuracy did not improve from 0.98315
# 13/13 - 14s - loss: 0.0748 - accuracy: 0.9746 - val_loss: 0.1324 - val_accuracy: 0.9663 - 14s/epoch - 1s/step

# %%
fish.evaluate(test_dataset , verbose = 1)
# Out:
# 2/2 [==============================] - 9s 8s/step - loss: 0.7867 - accuracy: 0.8191
# [0.7867324948310852, 0.8190954923629761]

# %%
plt.figure(figsize=(20, 15))
for images, labels in test_dataset.take(1):
    for i in range(25):
        plt.subplot(5,5,i+1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.axis("off")
        im2 = images[i].numpy().astype("uint8")
        img2 = tf.expand_dims(im2, 0)
        predict = fish.predict(img2)
        predicted= class_names[np.argmax(predict)]
        actual = class_names [labels[i].numpy().astype("uint8")]
        if (actual == predicted):
            plt.title(predicted, fontsize=10, color= 'blue', pad=15);
        else :
            plt.title(actual, fontsize=10, color= 'red' ,pad=15);
        plt.subplots_adjust(left=0.1,bottom=0.1, right=0.9,
                            top=0.9, wspace=0.4,hspace=0.4)
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step

# %%
acc = [0.] + history.history['accuracy']
val_acc = [0.] + history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(17, 12))
plt.subplot(2, 2, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,3.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
import numpy as np
from sklearn.metrics import classification_report, roc_auc_score, roc_curve, auc
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize

# Initialize empty lists to store true labels and predicted labels
true_labels = []
predicted_labels = []

# Iterate through the validation dataset and make predictions
for images, labels in test_dataset:
    predictions = fish.predict(images)
    predicted_labels.extend(np.argmax(predictions, axis=1))
    true_labels.extend(labels.numpy())

# Binarize the true and predicted labels
true_labels_bin = label_binarize(true_labels, classes=np.unique(true_labels))
predicted_labels_bin = label_binarize(predicted_labels, classes=np.unique(predicted_labels))

# Compute class-specific ROC AUC values
roc_auc_per_class = []
for i in range(len(class_names)):
    roc_auc = roc_auc_score(true_labels_bin[:, i], predicted_labels_bin[:, i])
    roc_auc_per_class.append(roc_auc)

# Generate the classification report
report = classification_report(true_labels, predicted_labels, target_names=class_names)

# Print class-specific ROC AUC values
for i in range(len(class_names)):
    print(f'ROC AUC for {class_names[i]}: {roc_auc_per_class[i]:.4f}')

# Print the classification report
print(report)
# Out:
# 4/4 [==============================] - 5s 126ms/step
# 3/3 [==============================] - 3s 1s/step
# ROC AUC for Argulus: 0.9306
# ROC AUC for Broken antennae and rostrum: 0.9914
# ROC AUC for EUS: 0.7178
# ROC AUC for Healthy Fish: 0.8587
# ROC AUC for Redspot: 0.7780
# ROC AUC for THE BACTERIAL GILL ROT: 0.9971
# ROC AUC for Tail And Fin Rot: 1.0000
#                              precision    recall  f1-score   support
#
#                     Argulus       0.81      0.90      0.85        29
# Broken antennae and rostrum       0.89      1.00      0.94        25
#                         EUS       0.64      0.48      0.55        29
#                Healthy Fish       0.76      0.76      0.76        29
#                     Redspot       0.62      0.62      0.62        29
#      THE BACTERIAL GILL ROT       0.97      1.00      0.98        29
#            Tail And Fin Rot       1.00      1.00      1.00        29
#
#                    accuracy                           0.82       199
#                   macro avg       0.81      0.82      0.82       199
#                weighted avg       0.81      0.82      0.81       199

# %%
from sklearn.metrics import classification_report, confusion_matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)

# Plot the confusion matrix as a heatmap
plt.figure(figsize=(5, 3))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix (ResNet-50)')
plt.show()

# %%
import numpy as np
from sklearn.metrics import classification_report, roc_auc_score, roc_curve, auc
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize

# Initialize empty lists to store true labels and predicted labels
true_labels = []
predicted_labels = []

# Iterate through the validation dataset and make predictions
for images, labels in test_dataset:
    predictions = fish.predict(images)
    predicted_labels.extend(np.argmax(predictions, axis=1))
    true_labels.extend(labels.numpy())

# Binarize the true and predicted labels
true_labels_bin = label_binarize(true_labels, classes=np.unique(true_labels))
predicted_labels_bin = label_binarize(predicted_labels, classes=np.unique(predicted_labels))

# Compute class-specific ROC AUC values
roc_auc_per_class = []
for i in range(len(class_names)):
    roc_auc = roc_auc_score(true_labels_bin[:, i], predicted_labels_bin[:, i])
    roc_auc_per_class.append(roc_auc)

# Generate the classification report
report = classification_report(true_labels, predicted_labels, target_names=class_names)

# Plot class-specific ROC curves
plt.figure(figsize=(10, 8))

for i in range(len(class_names)):
    fpr, tpr, _ = roc_curve(true_labels_bin[:, i], predicted_labels_bin[:, i])
    roc_auc = auc(fpr, tpr)

    plt.plot(fpr, tpr, label=f'ROC curve (area = {roc_auc:.2f}) for {class_names[i]}')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves for Multiclass Fish Diseases Classification (ResNet-50)')
plt.legend(loc='lower right')
plt.show()

# Print class-specific ROC AUC values
for i in range(len(class_names)):
    print(f'ROC AUC for {class_names[i]}: {roc_auc_per_class[i]:.4f}')

# Print the classification report
print(report)
# Out:
# 4/4 [==============================] - 1s 188ms/step
# 3/3 [==============================] - 0s 167ms/step
# ROC AUC for Argulus: 0.9306
# ROC AUC for Broken antennae and rostrum: 0.9914
# ROC AUC for EUS: 0.7178
# ROC AUC for Healthy Fish: 0.8587
# ROC AUC for Redspot: 0.7780
# ROC AUC for THE BACTERIAL GILL ROT: 0.9971
# ROC AUC for Tail And Fin Rot: 1.0000
#                              precision    recall  f1-score   support
#
#                     Argulus       0.81      0.90      0.85        29
# Broken antennae and rostrum       0.89      1.00      0.94        25
#                         EUS       0.64      0.48      0.55        29
#                Healthy Fish       0.76      0.76      0.76        29
#                     Redspot       0.62      0.62      0.62        29
#      THE BACTERIAL GILL ROT       0.97      1.00      0.98        29
#            Tail And Fin Rot       1.00      1.00      1.00        29
#
#                    accuracy                           0.82       199
#                   macro avg       0.81      0.82      0.82       199
#                weighted avg       0.81      0.82      0.81       199

# %%
from sklearn.metrics import cohen_kappa_score

kappa = cohen_kappa_score(true_labels, predicted_labels)
print(f'Cohen\'s Kappa: {kappa:.4f}')
# Out:
# Cohen's Kappa: 0.7889

# %%
from sklearn.metrics import matthews_corrcoef
import numpy as np

# Assuming true_labels and predicted_labels are your multiclass labels
mcc_values = [matthews_corrcoef(true_labels == i, predicted_labels == i) for i in np.unique(true_labels)]

average_mcc = np.mean(mcc_values)
print(f'Average Matthews Correlation Coefficient for Multiclass: {average_mcc:.4f}')
# Out:
# Average Matthews Correlation Coefficient for Multiclass: 0.7868

# %%
from sklearn.metrics import precision_recall_curve
import matplotlib.pyplot as plt

# %%
colors = ['blue', 'green', 'red', 'purple', 'orange','yellow','black']
